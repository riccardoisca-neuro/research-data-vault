# %% [markdown]
# <a href="https://colab.research.google.com/github/riccardoisca-neuro/research-data-vault/blob/main/sololearn-python-core/python_boolean_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# The program takes the score as an input
score = int(input())
# Add the comparison operation inside the parathenses
print (score>100)
# Out:
# 120
# True

# %%
# Take steps  and minutes as inputs
steps = int(input())
active_minutes = int(input())

# Store the result of the operations as a boolean in the variable
goal_achieved = steps > 10000 or active_minutes > 30

#Display the result on the screen
print (str(goal_achieved))
# Out:
# 800
# 25
# False

# %%
# Physical test score
physic_test = int(input())

# Flight simulation test score
flight_test = int(input())

# Combine the operation to get the final result
final_result = physic_test > 90 and flight_test > 85

# Display the result on the screen
print (str(final_result))
# Out:
# 96
# 84
# False
